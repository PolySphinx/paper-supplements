# %%
import warnings
warnings.filterwarnings("ignore")

from simulation.loopix import *
from simulation.apps import *
from simulation.messages import *
from simulation.multicast import *
from simulation.notebook_utils import *
import simulation.simrandom

import gc
import gzip
import copy
import itertools
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
import numpy as np
import os
import pickle
import pprint
import statistics
import sys
import time

from collections import namedtuple

# %config InlineBackend.figure_format = 'retina'

# Avoid type 3 fonts
plt.rc('pdf', fonttype=42)

# %%
class SimResult(object):
    
    def __init__(self, m, group_sizes, config_name, schedule_name, strategy_name):
        self.name = get_name(m, group_sizes, config_name, schedule_name, strategy_name)
        self.m = m
        self.group_sizes = group_sizes
        self.config_name = config_name
        self.schedule_name = schedule_name
        self.strategy_name = strategy_name
        self.sim_time_ms = 0
        
    @property
    def config_strategy(self):
        return (self.config_name, self.strategy_name)
        
    def output_filename(self):
        return os.path.join('pickles', self.name + ".output")
    
    def __repr__(self):
        return self.name

# %% [markdown]
# # Loading

# %%
def read_data(groupsizes, configs, schedules, strategies):
    data = []
    for m, group_sizes in groupsizes:
        for config_name in configs:
            for schedule_name in schedules:
                for strategy_name in strategies:
                    data.append(SimResult(m, group_sizes, config_name, schedule_name, strategy_name))
    return data

# [!] CHANGE `24` to `1` for shorter simulations
DEFAULT_MS = 24 * 3600 * 1000

DEFAULT_SCHEDULES = ['gen_os10', 'gen_os15', 'gen_os20']

# %%
# ONLINE scenarios
ONLINE_GROUP_SIZES = [
    (25, [25]),
    (32, [32]),
    (45, [45]),
    (64, [64]),
    (91, [91]),
    (128, [128]),
    (181, [181]),
    (256, [256]),
]
ONLINE_CONFIGS = ['rs']
ONLINE_SCHEDULES = ['online']
ONLINE_STRATEGIES = [
    'unicast',
    'unicast-p2',
    'unicast-p5',
    'rollercoaster-k1-p1-notimeout',
    'rollercoaster-k2-p2-notimeout',
    'polysphinx-p2-l1',
    'polysphinx-p2-l2',
    'polysphinx-p5-l1',
    'polysphinx-p5-l2',
]

online_data = []
online_data.extend(read_data(ONLINE_GROUP_SIZES, ['rs'], ONLINE_SCHEDULES, ['unicast', 'unicast-p2', 'unicast-p5', 'rollercoaster-k1-p1-notimeout', 'rollercoaster-k2-p2-notimeout']))
online_data.extend(read_data(ONLINE_GROUP_SIZES, ['ps-2'], ONLINE_SCHEDULES, ['polysphinx-p2-l1']))
online_data.extend(read_data(ONLINE_GROUP_SIZES, ['ps-5'], ONLINE_SCHEDULES, ['polysphinx-p5-l1']))
online_data.extend(read_data(ONLINE_GROUP_SIZES, ['baseline'], ONLINE_SCHEDULES, ['unicast']))

# %%
all_datas = [online_data]

# %%
def load_results(data, incl_scatter=False):
    start = time.time()
    for sr in data:
        npz_filename = sr.output_filename() + '.npz'
        sys.stdout.write('.')
        sys.stdout.flush()
        
        with np.load(npz_filename) as npz:
            sr.sim_time_ms = npz['sim_time_ms'][0]

            sr.e2e_entries_d = npz['e2e_entries_d']
            sr.e2e_entries_online_d = npz['e2e_entries_online_d']
            if incl_scatter:
                sr.e2e_entries_t = npz['e2e_entries_t']
                sr.e2e_entries_online_t = npz['e2e_entries_online_t']
#             sr.already_seen = npz['already_seen']
#             sr.payload_buffer_levels = npz['payload_buffer_levels']
#             sr.payload_buffer_levels_t = npz['payload_buffer_levels_t']
        del npz
    print("\nLoaded #data:", len(data), "(%.1fs)" % (time.time() - start))
    
load_results(online_data, incl_scatter=False)
# Out:
# ................................................................
# Loaded #data: 64 (0.1s)

# %%
def print_stats(name, data):
    print()
    print("-- %s --" % name.upper())
    total_sim_time = int(sum([sim.sim_time_ms for sim in data])/3_600_000)
    total_count_messages = sum([len(sim.e2e_entries_d) for sim in data])
    total_count_messages_online = sum([len(sim.e2e_entries_online_d) for sim in data])
    print(f"Total simulated time (walltime hours): {total_sim_time:,}")
    print(f"Total messages: {total_count_messages:,}")
    print(f"Total messages (online-only): {total_count_messages_online:,}")
    
print_stats(
    "TOTAL",
    sum(all_datas, [])
)
# Out:
# -- TOTAL --
# Total simulated time (walltime hours): 64
# Total messages: 755,695
# Total messages (online-only): 755,695

# %% [markdown]
# # Definitons

# %%
#
# Filter methods
#

def filter_results(data, **kwargs):
    result = []
    for r in data:
        match = True
        for k, v in kwargs.items():
            if getattr(r, k) != v:
                match = False
                break
        if match:
            result.append(r)
    return result

Row = namedtuple('Row', ['label', 'value', 'cols'])
Col = namedtuple('Col', ['label', 'value', 'd'])

def group_results(data, y_grouping, y_values, x_grouping, x_values):
    assert x_grouping != y_grouping
    
    rows = []
    for y_value in y_values:
        row = Row(get_category_value_label(y_grouping, y_value), y_value, [])
        rows.append(row)
        
        for x_value in x_values:
            d = filter_results(data, **{y_grouping: y_value, x_grouping: x_value})
            assert len(d) == 1, "len(d)==%d, y_value=%s, x_value=%s" % (len(d), str(y_value), str(x_value))
            
            row.cols.append(Col(get_category_value_label(x_grouping, x_value), x_value, d))
            
    return rows

# %%
#
# Labels and colours
#

def get_category_value_label(category, value):
    if category == 'm':
        return ' $m=%s$' % str(value)
    elif category == 'strategy_name':
        substrings = {
            # default
            'unicast-p2': "Unicast ($p=2$)",
            'unicast-p5': "Unicast ($p=5$)",
            'unicast': "Unicast",
            
            'polysphinx-p2': "PolySphinx ($p=2$)",
            'polysphinx-p5': "PolySphinx ($p=5$)",
            
            'rollercoaster-k1-p1-notimeout': "RC ($k=p=1$)",
            'rollercoaster-k2-p2-notimeout': "RC ($k=p=2$)",
            'rollercoaster-k1-p2-notimeout': "RC ($k=1, p=2$)",
            'rollercoaster-k2-p1-notimeout': "RC ($k=2, p=1$)",
            'rollercoaster-k3-p3-notimeout': "RC ($k=p=3$)",
        }
        for ss, vv in substrings.items():
            if ss in value:
                return vv
    elif category == 'config_name':
        try:
            return {
                'rs': " $1$",
                'rs-m2': " $2$",
                'rs-m4': " $4$",
                'rs-m8': " $8$",
                'rs-m16': " $16$",
                'rs-m32': " $32$",
            }[value]
        except KeyError:
            return str(value)
    elif category == 'schedule_name':
        return {
            'gen_os10': " $65\\%$ online",
            'gen_os15': " $80\\%$ online",
            'gen_os20': " $88\\%$ online",
            'online': " $100\\%$ online",
        }[value]
    elif category == 'group_sizes':
        return len(value)
    elif category == 'config_strategy':
        if value == ('baseline', 'unicast'):
            return 'Unicast (5 packets per round)'
        return get_category_value_label('strategy_name', value[1])
    else:
        assert False, "unknown category %s" % str(category)

cmap = plt.get_cmap("tab20")      
def get_color(category, value):
    if category == 'strategy_name':
        substrings = {
            # default
            'unicast-p2': cmap(1),
            'unicast-p5': cmap(13),
            'unicast': cmap(0),
            
            'rollercoaster-k1-p1-notimeout': cmap(5),
            'rollercoaster-k1-p2-notimeout': cmap(14-8),
            'rollercoaster-k2-p1-notimeout': cmap(15-8),
            'rollercoaster-k2-p2-notimeout': cmap(4),
            'rollercoaster-k3-p3-notimeout': cmap(5),
            
            # polysphinx
            'polysphinx-p2-l2': cmap(9),
            'polysphinx-p2-l1': cmap(10),
            'polysphinx-p5-l2': cmap(11),
            'polysphinx-p5-l1': cmap(12),     
        }
        for ss, vv in substrings.items():
            if ss in value:
                return vv
        print("unknown strategy_name %s" % value)
        return cmap(0)
    elif category == 'config_strategy':
        if value == ('baseline', 'unicast'):
            return cmap(14)
        return get_color('strategy_name', value[1])
    assert False, "unknown category %s" % str(category)

# %%
#
# General helper methods
#

def quantile(quantile, data):
    data = sorted(data)
    return data[int(len(data) * quantile)]

def plot_and_save(fig, name, save=False, pdf=True, png=True):
    plt.tight_layout()
    plt.show()
    
    if save:
        fig.savefig('output/%s.pdf' % name, bbox_inches='tight', pad_inches=0.075) if pdf else None
        fig.savefig('output/%s.png' % name, dpi=450, bbox_inches='tight', pad_inches=0.075) if png else None

# %%
#
# Scatter
#

def scatter_plot(
    data,
    y_grouping, y_values,
    x_grouping, x_values,
    figsize=(12, 2.75),
    zoom_range=(1200, 1600),
    ylim=100, use_log=False,
    online_only=False,
    print_progress=False,
):
    table = group_results(
        data,
        y_grouping=y_grouping, y_values=y_values,
        x_grouping=x_grouping, x_values=x_values,
    )
    zoom_left, zoom_right =  zoom_range[0]*1000, zoom_range[1]*1000
    
    fig = plt.figure(figsize=figsize)
    
    first_ax, idx = None, 1
    for y_idx, row in enumerate(table):
        for x_idx, col in enumerate(row.cols):
            ax = fig.add_subplot(
                len(table), len(row.cols), idx,
                sharex=first_ax, sharey=first_ax
            )
            first_ax = first_ax if first_ax else ax
            
            d = col.d[0]
            if online_only:
                data = zip(d.e2e_entries_online_t, d.e2e_entries_online_d)
            else:
                data = zip(d.e2e_entries_t, d.e2e_entries_d)
                
            x, y = [], []
            for t, d in data:
                if t < zoom_left: continue
                if t > zoom_right: break
                x.append(t)
                y.append(d)
            
            ax.plot(x, y, '+', markersize=3, alpha=0.5, color=get_color(x_grouping, col.value))
            if use_log:
                ax.set_yscale('log')
        
            ax.xaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda v, pos: int(v/1000)))
            ax.yaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda v, pos: int(v/1000)))

            if y_idx == len(table)-1:
                ax.set_xlabel("Arrival time of message [s]\n%s" % col.label)
                
            if x_idx == 0:
                ax.set_ylabel("Message latency $d_{msg}$ [s]\n%s" % row.label)

            ax.set_xlim((zoom_left, zoom_right))
            ax.set_ylim((1_000, ylim * 1_000))

            ax.grid(linestyle='solid', linewidth='0.5')

            idx += 1
            
            if print_progress:
                print("idx:", idx, "of", len(table)*len(row.cols))
        
    return fig

# %%
#
# Histogram
#

def hist_plot(
    data,
    y_grouping, y_values,
    x_grouping, x_values,
    figsize=(12, 4.36),
    link_y=False,
    show_outliers=False,
    xlim=100,
):
    xlim = xlim * 1_000
    
    table = group_results(
        data,
        y_grouping=y_grouping, y_values=y_values,
        x_grouping=x_grouping, x_values=x_values,
    )
    
    fig = plt.figure(figsize=figsize)
    
    first_ax, idx = None, 1
    for y_idx, row in enumerate(table):
        for x_idx, col in enumerate(row.cols):
            ax = fig.add_subplot(
                len(table), len(row.cols), idx,
                sharex=first_ax, sharey=first_ax if link_y else None
            )
            first_ax = first_ax if first_ax else ax

            if y_idx == len(table)-1:
                ax.set_xlabel("Message latency $d_{msg}$ [s]\n%s" % col.label)
                
            if x_idx == 0:
                ax.set_ylabel("Frequency\n%s" % row.label)
                

            ax.set_xlim((0, xlim))

            ax.xaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda v, pos: int(v/1000)))   
            ax.yaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda v, pos: ("%.0fk" % (v/1_000))))
            
            ax.set_axisbelow(True)
            ax.grid(linewidth='1', linestyle='solid', axis="x", which='major', alpha=0.5)

            d = col.d[0].e2e_entries_online_d
            hist_values, _, _ = ax.hist(d, bins=50, range=(0, xlim), color=get_color(x_grouping, col.value))
            ax.set_yticks([0, max(hist_values)])

            mean, q90, q99 =  np.mean(d), np.quantile(d, 0.90), np.quantile(d, 0.99)
            ax.axvline([mean], color='black')
            ax.axvline([q90], color='black', ls='--')
            ax.axvline([q99], color='black', ls=':')
            
            if show_outliers:
                annot_text = ""
                if mean > xlim:
                    annot_text += "$mean=%.1f$s" % (mean / 1000)
                if q90 > xlim:
                    annot_text += "\n" if annot_text else ""
                    annot_text += "$p_{90}=%.1f$s" % (q90 / 1000)
                if q99 > xlim:
                    annot_text += "\n" if annot_text else ""
                    annot_text += "$p_{99}=%.1f$s" % (q99 / 1000)

                if annot_text:
                    ax.annotate(
                        annot_text,
                        xy=(1, 0.5), xycoords='axes fraction',
                        xytext=(0.9,0.5), textcoords='axes fraction', ha="right", va="center",
                        size=8,
                        arrowprops=dict(arrowstyle="->"),
                        bbox=dict(boxstyle="round,pad=0.5", fc="white",ec='lightgrey',lw=1),
                    )
        
            idx += 1
            
    return fig

# %%
#
# Table
#

def print_row(d):
    delays = d.e2e_entries_online_d
    print(
        "%3d %20s %10s %32s %6.1f %6.1f %6.1f %6.1f" % (
            d.m,
            d.config_name,
            d.schedule_name,
            d.strategy_name,
            np.mean(delays)/1000,
            np.quantile(delays, 0.75)/1000,
            np.quantile(delays, 0.90)/1000,
            np.quantile(delays, 0.99)/1000
    ))
    
    
def print_table(data):
    header = "%-3s %-20s %-10s %-32s %-6s %-6s %-6s %-6s [seconds]" % (
            "m",
            "config_name",
            "schedule_name",
            "strategy_name",
            "mean",
            "p75",
            "p90",
            "p99",
    )
    print(header)
    print("-"*len(header))
    for d in data:
        print_row(d)

# %%
#
# Groupped bars
#

def bar_plot(
    data,
    y_grouping, y_values,
    x_grouping, x_values,
    figsize=(6, 4),
    ylim=100, use_log=False,
    y_grouping_label = None,
    ax=None,
    show_legend=True,
):
    """y-grouping -> outer-grouping, x-grouping -> inner-grouping"""
    ylim = ylim * 1_000
    table = group_results(
        data,
        y_grouping=y_grouping, y_values=y_values,
        x_grouping=x_grouping, x_values=x_values,
    )
    
    if not ax:
        fig = plt.figure(figsize=figsize)
        ax = fig.add_subplot(1, 1, 1)
    else:
        fig = None
    
    plots_per_group = len(x_values)
    num_groups = len(y_values)

    for outer_idx, row in enumerate(table):
        values = [col.d[0].e2e_entries_online_d for col in row.cols]
        positions = [outer_idx*(plots_per_group+1) + i for i in range(plots_per_group)]
        boxplot = ax.boxplot(
            values, 
            positions = positions, 
            patch_artist=True,
            widths = 0.8, showfliers=False, whis=[1, 99],
            sym='x',
        )

        for patch, col in zip(boxplot['boxes'], row.cols):
            patch.set_facecolor(get_color(x_grouping, col.value))
        for patch in boxplot['fliers']:
            patch.set_alpha(0.5)
        for median in boxplot['medians']:
            plt.setp(median, color='black')

    ax.grid(linewidth='1', linestyle='solid', axis="y", which='major', alpha=0.5)

    ax.set_xlabel(y_grouping_label if y_grouping_label else str(y_grouping))
    ax.set_xticks([plots_per_group//2 + i*(plots_per_group+1) for i in range(num_groups)])
    ax.set_xticklabels([get_category_value_label(y_grouping, row.value) for row in table])

    ax.set_ylabel("Message latency\n$d_{msg}$ [s]")
    ax.set_ylim(1_000 if use_log else 0, ylim)
    
    if use_log:
        ax.set_yscale('log')
        
    ax.yaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda v, pos: int(v/1000)))
    
    if not use_log:
        ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(10_000))

    handles_labels = (
        [boxplot['boxes'][i] for i in range(len(x_values))],
        [get_category_value_label(x_grouping, x) for x in x_values],
    )
        
    if show_legend:
        ll= ax.legend(handles_labels[0], handles_labels[1], loc='upper left')

    
    return fig, ax, handles_labels

# %%
#
# Line plot
#

def line_plot(
    data,
    x_grouping, x_values,
    color_grouping, color_values,
    figsize,
    x_grouping_label=None,
    ylim = 100,
):
    ylim = ylim * 1_000
    table = group_results(
        data,
        y_grouping=color_grouping, y_values=color_values,
        x_grouping=x_grouping, x_values=x_values,
    )
    
    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot(1, 1, 1)
    
    for outer_idx, row in enumerate(table):
        values = [col.d[0].e2e_entries_online_d for col in row.cols]
        
        means = [np.mean(x) for x in values]
        q90 = [np.quantile(x, 0.99) for x in values]
        handle = ax.errorbar(
            x=x_values, y=means, 
            fmt='o', ls='-', 
            color=get_color(color_grouping, row.value),
            ms=4, capsize=4
        )
        ax.errorbar(
            x=x_values, y=q90, 
            color=get_color(color_grouping, row.value),
            fmt='', ls=':', 
        )
        handle.set_label(get_category_value_label(color_grouping, row.value))
        

    ax.grid(linewidth='1', linestyle='solid', axis="both", which='major', alpha=0.5)

    ax.set_xlabel(x_grouping_label if x_grouping_label else str(x_grouping))
    ax.set_xscale("log")
    ax.set_xticks(x_values)
    ax.minorticks_off()
    ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())

    ax.set_ylabel("Message latency\n$d_{msg}$ [s]")
    ax.set_ylim(0, ylim)
    ax.yaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda v, pos: int(v/1000)))
    ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(10_000))

    return fig, ax, ax.get_legend_handles_labels()

# %%
def add_figure_legend(fig, ax, handles_labels, offset, ncols=3):
    # Shrink current axis by 10%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
    
    fig.legend(
        handles_labels[0], handles_labels[1], loc='center left', ncol=ncols, 
        bbox_to_anchor=(1, 0.5 + offset),
        frameon=False)

# %% [markdown]
# # Standard plots

# %% [markdown]
# ## Online

# %%
online_config_name = 'rs'
y_groups = [25, 32, 64, 128]

# %%
fig = hist_plot(
    filter_results(online_data, config_name=online_config_name),
    y_grouping='m', y_values=y_groups,
    x_grouping='strategy_name', x_values=[ONLINE_STRATEGIES[x] for x in [0, 3, 4]],
    figsize=(12, 6),
    link_y=False,
    show_outliers=True,
)
plot_and_save(fig, "graph_online_hist", True)

# %%
#fig = hist_plot(
#    filter_results(online_data, config_name=online_config_name),
#    y_grouping='m', y_values=y_groups,
#    x_grouping='strategy_name', x_values=[ONLINE_STRATEGIES[x] for x in [1, 5, 6]],
#    figsize=(12, 6),
#    link_y=False,
#    show_outliers=True,
#)
#plot_and_save(fig, "polysphinx_graph_online_hist_p2", True)

# %%
#fig = hist_plot(
#    filter_results(online_data, config_name=online_config_name),
#    y_grouping='m', y_values=y_groups,
#    x_grouping='strategy_name', x_values=[ONLINE_STRATEGIES[x] for x in [2, 7, 8]],
#    figsize=(12, 6),
#    link_y=False,
#    show_outliers=True,
#)
#plot_and_save(fig, "polysphinx_graph_online_hist_p5", True)

# %%
compared_data = []
compared_data.extend(filter_results(online_data, config_name='rs'))
compared_data.extend(filter_results(online_data, config_name='ps-2'))
compared_data.extend(filter_results(online_data, config_name='ps-5'))
compared_data.extend(filter_results(online_data, config_name='baseline'))

fig, ax, handles_labels = bar_plot(
    compared_data,
    y_grouping='m', y_values=[x[0] for x in ONLINE_GROUP_SIZES], y_grouping_label='Group size',
    x_grouping='config_strategy', x_values=[
        ("rs", "unicast"),
        ("baseline", "unicast"),
        ("ps-2", "polysphinx-p2-l1"),
        ("ps-5", "polysphinx-p5-l1"),
        ("rs", "rollercoaster-k1-p1-notimeout"),
        # Rollercoaster p=2 is normalized for outgoing message rate,
        # not for bandwidth - we therefore leave it out.
        # ("rs", "rollercoaster-k2-p2-notimeout"),
    ],
    figsize=(11, 3.25),
    ylim=90,
    show_legend=False
)

add_figure_legend(
    fig,
    ax,
    handles_labels,
    offset=0.07,
    ncols=1,
)
plot_and_save(fig, "graph_online_bar", True)

# %% [markdown]
# # Result variables

# %%
#
# These results are included in the main text of the paper via LaTeX variables
#

def print_cmd(name, value):
    print("\\newcommand{\\%s}{%.1f}" % (name, value))
    
def print_p99_cmd(name, data):
    assert len(data) == 1
    print_cmd(name, p99(data[0].e2e_entries_online_d))
    
def print_p90_cmd(name, data):
    assert len(data) == 1
    print_cmd(name, p90(data[0].e2e_entries_online_d))
    
def print_mean_cmd(name, data):
    assert len(data) == 1
    print_cmd(name, np.average(data[0].e2e_entries_online_d) / 1000)
    
def print_sem_cmd(name, data):
    assert len(data) == 1
    print_cmd(name, np.std(data[0].e2e_entries_online_d) / np.sqrt(len(data[0].e2e_entries_online_d)))
    
def p99(x):
    return np.quantile(x, 0.99) / 1000
    
def p90(x):
    return np.quantile(x, 0.90) / 1000

print("% percentile always p99; except PercentileSmall which is p90")
print("% realistic = 25")
print("% verysmall = 32")
print("% small = 45")
print("% medium = 64")
print("% large = 128")
print("% verylarge = 256")
print("% Note that SEM is in milliseconds because it is rather small")
print("% Rest is in seconds")

for printer, printer_name in [
    (print_p99_cmd, "Percentile"),
    (print_p90_cmd, "PercentileSmall"),
    (print_mean_cmd, "Mean"),
    (print_sem_cmd, "SEM"),
]:
    for group_size, size_name in [
        (25, "Realistic"),
        (32, "VerySmall"),
        (45, "Small"),
        (64, "Medium"),
        (128, "Large"),
        (256, "VeryLarge"),
    ]:
        for config, strategy, strategy_name in [
            ("rs", "rollercoaster-k1-p1-notimeout", "Rc"),
            ("rs", "unicast", "Unicast"),
            ("ps-5", "polysphinx-p5-l1", "Polysphinx"),
            ("baseline", "unicast", "Baseline"),
        ]:
            cmd_name = f"measurement{printer_name}Online{size_name}{strategy_name}"
            printer(
                cmd_name, 
                filter_results(online_data, config_name=config, m=group_size, schedule_name="online", strategy_name=strategy),
            )
# Out:
# % percentile always p99; except PercentileSmall which is p90
# % realistic = 25
# % verysmall = 32
# % small = 45
# % medium = 64
# % large = 128
# % verylarge = 256
# % Note that SEM is in milliseconds because it is rather small
# % Rest is in seconds
# \newcommand{\measurementPercentileOnlineRealisticRc}{12.7}
# \newcommand{\measurementPercentileOnlineRealisticUnicast}{18.4}
# \newcommand{\measurementPercentileOnlineRealisticPolysphinx}{9.6}
# \newcommand{\measurementPercentileOnlineRealisticBaseline}{7.7}
# \newcommand{\measurementPercentileOnlineVerySmallRc}{13.5}
# \newcommand{\measurementPercentileOnlineVerySmallUnicast}{21.2}
# \newcommand{\measurementPercentileOnlineVerySmallPolysphinx}{10.3}
# \newcommand{\measurementPercentileOnlineVerySmallBaseline}{7.8}
# \newcommand{\measurementPercentileOnlineSmallRc}{14.4}
# \newcommand{\measurementPercentileOnlineSmallUnicast}{28.8}
# \newcommand{\measurementPercentileOnlineSmallPolysphinx}{12.3}
# \newcommand{\measurementPercentileOnlineSmallBaseline}{8.8}
# \newcommand{\measurementPercentileOnlineMediumRc}{16.1}
# \newcommand{\measurementPercentileOnlineMediumUnicast}{48.9}
# \newcommand{\measurementPercentileOnlineMediumPolysphinx}{17.3}
# \newcommand{\measurementPercentileOnlineMediumBaseline}{10.9}
# \newcommand{\measurementPercentileOnlineLargeRc}{18.7}
# \newcommand{\measurementPercentileOnlineLargeUnicast}{72.8}
# \newcommand{\measurementPercentileOnlineLargePolysphinx}{27.5}
# \newcommand{\measurementPercentileOnlineLargeBaseline}{18.9}
# \newcommand{\measurementPercentileOnlineVeryLargeRc}{20.7}
# \newcommand{\measurementPercentileOnlineVeryLargeUnicast}{179.1}
# \newcommand{\measurementPercentileOnlineVeryLargePolysphinx}{46.4}
# \newcommand{\measurementPercentileOnlineVeryLargeBaseline}{31.2}
# \newcommand{\measurementPercentileSmallOnlineRealisticRc}{9.6}
# \newcommand{\measurementPercentileSmallOnlineRealisticUnicast}{13.5}
# \newcommand{\measurementPercentileSmallOnlineRealisticPolysphinx}{6.7}
# \newcommand{\measurementPercentileSmallOnlineRealisticBaseline}{5.3}
# \newcommand{\measurementPercentileSmallOnlineVerySmallRc}{10.5}
# \newcommand{\measurementPercentileSmallOnlineVerySmallUnicast}{16.8}
# \newcommand{\measurementPercentileSmallOnlineVerySmallPolysphinx}{7.3}
# \newcommand{\measurementPercentileSmallOnlineVerySmallBaseline}{5.8}
# \newcommand{\measurementPercentileSmallOnlineSmallRc}{10.9}
# \newcommand{\measurementPercentileSmallOnlineSmallUnicast}{22.5}
# \newcommand{\measurementPercentileSmallOnlineSmallPolysphinx}{9.1}
# \newcommand{\measurementPercentileSmallOnlineSmallBaseline}{6.6}
# \newcommand{\measurementPercentileSmallOnlineMediumRc}{12.4}
# \newcommand{\measurementPercentileSmallOnlineMediumUnicast}{32.4}
# \newcommand{\measurementPercentileSmallOnlineMediumPolysphinx}{12.0}
# \newcommand{\measurementPercentileSmallOnlineMediumBaseline}{8.4}
# \newcommand{\measurementPercentileSmallOnlineLargeRc}{14.6}
# \newcommand{\measurementPercentileSmallOnlineLargeUnicast}{60.5}
# \newcommand{\measurementPercentileSmallOnlineLargePolysphinx}{20.7}
# \newcommand{\measurementPercentileSmallOnlineLargeBaseline}{14.5}
# \newcommand{\measurementPercentileSmallOnlineVeryLargeRc}{16.3}
# \newcommand{\measurementPercentileSmallOnlineVeryLargeUnicast}{121.5}
# \newcommand{\measurementPercentileSmallOnlineVeryLargePolysphinx}{37.7}
# \newcommand{\measurementPercentileSmallOnlineVeryLargeBaseline}{25.3}
# \newcommand{\measurementMeanOnlineRealisticRc}{6.4}
# \newcommand{\measurementMeanOnlineRealisticUnicast}{8.3}
# \newcommand{\measurementMeanOnlineRealisticPolysphinx}{4.1}
# \newcommand{\measurementMeanOnlineRealisticBaseline}{3.4}
# \newcommand{\measurementMeanOnlineVerySmallRc}{6.9}
# \newcommand{\measurementMeanOnlineVerySmallUnicast}{9.9}
# \newcommand{\measurementMeanOnlineVerySmallPolysphinx}{4.5}
# \newcommand{\measurementMeanOnlineVerySmallBaseline}{3.7}
# \newcommand{\measurementMeanOnlineSmallRc}{7.3}
# \newcommand{\measurementMeanOnlineSmallUnicast}{13.2}
# \newcommand{\measurementMeanOnlineSmallPolysphinx}{5.6}
# \newcommand{\measurementMeanOnlineSmallBaseline}{4.3}
# \newcommand{\measurementMeanOnlineMediumRc}{8.4}
# \newcommand{\measurementMeanOnlineMediumUnicast}{18.9}
# \newcommand{\measurementMeanOnlineMediumPolysphinx}{7.1}
# \newcommand{\measurementMeanOnlineMediumBaseline}{5.2}
# \newcommand{\measurementMeanOnlineLargeRc}{10.1}
# \newcommand{\measurementMeanOnlineLargeUnicast}{34.6}
# \newcommand{\measurementMeanOnlineLargePolysphinx}{12.2}
# \newcommand{\measurementMeanOnlineLargeBaseline}{8.8}
# \newcommand{\measurementMeanOnlineVeryLargeRc}{11.4}
# \newcommand{\measurementMeanOnlineVeryLargeUnicast}{69.4}
# \newcommand{\measurementMeanOnlineVeryLargePolysphinx}{21.4}
# \newcommand{\measurementMeanOnlineVeryLargeBaseline}{14.9}
# \newcommand{\measurementSEMOnlineRealisticRc}{43.0}
# \newcommand{\measurementSEMOnlineRealisticUnicast}{74.9}
# \newcommand{\measurementSEMOnlineRealisticPolysphinx}{33.5}
# \newcommand{\measurementSEMOnlineRealisticBaseline}{25.8}
# \newcommand{\measurementSEMOnlineVerySmallRc}{46.2}
# \newcommand{\measurementSEMOnlineVerySmallUnicast}{84.4}
# \newcommand{\measurementSEMOnlineVerySmallPolysphinx}{31.6}
# \newcommand{\measurementSEMOnlineVerySmallBaseline}{23.0}
# \newcommand{\measurementSEMOnlineSmallRc}{39.0}
# \newcommand{\measurementSEMOnlineSmallUnicast}{98.8}
# \newcommand{\measurementSEMOnlineSmallPolysphinx}{35.2}
# \newcommand{\measurementSEMOnlineSmallBaseline}{23.8}
# \newcommand{\measurementSEMOnlineMediumRc}{34.0}
# \newcommand{\measurementSEMOnlineMediumUnicast}{130.8}
# \newcommand{\measurementSEMOnlineMediumPolysphinx}{44.7}
# \newcommand{\measurementSEMOnlineMediumBaseline}{24.5}
# \newcommand{\measurementSEMOnlineLargeRc}{29.2}
# \newcommand{\measurementSEMOnlineLargeUnicast}{170.4}
# \newcommand{\measurementSEMOnlineLargePolysphinx}{53.9}
# \newcommand{\measurementSEMOnlineLargeBaseline}{34.6}
# \newcommand{\measurementSEMOnlineVeryLargeRc}{21.0}
# \newcommand{\measurementSEMOnlineVeryLargeUnicast}{226.0}
# \newcommand{\measurementSEMOnlineVeryLargePolysphinx}{68.6}
# \newcommand{\measurementSEMOnlineVeryLargeBaseline}{44.6}
